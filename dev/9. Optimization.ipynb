# %%
from utils import runwrite
import matplotlib.pyplot as plt

# %% [markdown]
# # optimize.py
#
# allow optimizing every paramters of Pipeline.add() using optuna, including:
#
# * feature engineering,
# * target engineering,
# * strategy,
# * modelling

# %%
# %%runwrite ../timegym/optimize.py
#
# import numpy as np
# import pandas as pd

# %%
# %%runwrite -a ../timegym/optimize.py
#
# # TODO
