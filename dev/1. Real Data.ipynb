# %%
from utils import runwrite
import matplotlib.pyplot as plt

# %% [markdown]
# # data/real.py

# %%
# %%runwrite ../timegym/data/real.py
#
# import numpy as np
# import pandas as pd

# %% [markdown]
# # Stocks

# %%
# %%runwrite -a ../timegym/data/real.py
#
# def get_stock(ticker, columns='Close'):
#     import yfinance
#     stock = yfinance.Ticker(ticker).history(period='max', auto_adjust=False)
#     #stock = stock.drop(columns=['Adj Close'])
#     return stock[columns]

# %%
# TODO add stocks
# TODO add m4_competition
# TODO add m5_competition
# TODO add ltorgo
# TODO add rdatasets
# TODO gather all public datasets of timeseries with at least 1 year of time series )
