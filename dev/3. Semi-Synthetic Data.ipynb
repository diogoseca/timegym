# %% [markdown]
# ### Foreword
#
# Semi-synthetic data has the following advantages over real data:
#
# * We can generate a lot more of it. Big data is good for ML, and great for DL.
# * The models we learn should be able to resist noise, and outliers, since we can inject as many of those into the data as we want.
#
# The cons:
#
# * Are we learning models that summarize the patterns found in the data? Or are we learning models that summarize the training set?
#
# Let us see..

# %%
from utils import runwrite
import matplotlib.pyplot as plt

# %% [markdown]
# # data/semisynthetic.py

# %%
# %%runwrite ../timegym/data/semisynthetic.py
#
# import numpy as np
# import pandas as pd

# %%
# TODO depends on synthetic data, and smoothing
# TODO take a real time series, smooth it using gaussian processes or other method.
# Sample a time series from this model
# Or use VAEs, or GANs, or another generative model

# %% [markdown]
# ## Echoflow ?

# %% [markdown]
# https://kevz.dev/echoflow
#
# https://k15z.github.io/EchoFlow/notebooks/1%20Getting%20Started.html

# %%
# TODO

# %% [markdown]
# ## SDV time series?
# https://sdv.dev/SDV/user_guides/timeseries/par.html

# %%
# TODO
